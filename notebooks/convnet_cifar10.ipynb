# %% [markdown]
# ## Needed Import

# %%
from pprint import pprint
from numpy import reshape
from keras import Model
from keras.models import load_model
from keras.utils.vis_utils import plot_model
from keras.datasets import cifar10
from keras.utils import to_categorical
from keras.optimizers import sgd
from keras.callbacks import TensorBoard
from keras.activations import relu, sigmoid
from keras.metrics import categorical_accuracy, mse
from keras.layers import Input, Dense, Conv2D, MaxPooling2D, Flatten

# %% [markdown]
# ## Data Preproccesing

# %%
experiment_name = 'CIPHAR10_CONVNET_128_MAXPOOL_1_33_256D_LR_01_DCY_1E-4_MMT_0.9_N_RELU'
tb_callback = TensorBoard('../logs/' + experiment_name)

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

x_train = reshape(x_train, (-1, 32, 32, 3)) / 255.0
x_test = reshape(x_test, (-1, 32, 32, 3)) / 255.0

# %% [markdown]
# ## Model Design

# %%
inputs = Input((32, 32, 3))
hidden = Conv2D(128, (4, 4), padding='same', activation=relu)(inputs)

pool_layers = MaxPooling2D((3, 3))(hidden)
flatten = Flatten()(pool_layers)
hidden_dense = Dense(256, activation=relu)(flatten)
outputs = Dense(10, activation=sigmoid)(hidden_dense)

model = Model(inputs, outputs)

# %% [markdown]
# ## Compilation of the model

# %% [markdown]
# model.compile(sgd(lr=0.1, decay=1e-4, momentum=0.9, nesterov=True),
#               mse, metrics=[categorical_accuracy])

# %% [markdown]
# ## Fitting the data

# %% [markdown]
# model.fit(x_train, y_train,
#           batch_size=512,
#           epochs=120,
#           callbacks=[tb_callback],
#           validation_data=(x_test, y_test))

# %% [markdown]
# ## Summary of the model

# %%
model = load_model('../model_save/CIPHAR10_CONVNET_128_MAXPOOL_1_33_256D_LR_01_DCY_1E-4_MMT_0.9_N_RELU.h5')
print(model.summary())
pprint(model.get_weights())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 32, 32, 3)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 128)       6272
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 10, 10, 128)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 12800)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               3277056
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 3,285,898
# Trainable params: 3,285,898
# Non-trainable params: 0
# _________________________________________________________________
# None
# [array([[[[             nan,              nan,              nan, ...,
#                        nan,              nan,              nan],
#          [             nan,  -1.74128847e+38,              nan, ...,
#                        nan,              nan,              nan],
#          [ -2.97747051e+38,              nan,              nan, ...,
#                        nan,              nan,              nan]],
#
#         [[             nan,              nan,              nan, ...,
#                        nan,              nan,              nan],
#          [             nan,              nan,              nan, ...,
#                        nan,              nan,              nan],
#          [             nan,  -1.70141173e+38,              nan, ...,
#                        nan,              nan,              nan]],
#
#         [[             nan,              nan,              nan, ...,
#                        nan,              nan,              nan],
#          [             nan,              nan,              nan, ...,
#                        nan,              nan,              nan],
#          [             nan,              nan,              nan, ...,
#            -3.40282347e+38,              nan,              nan]],
#
#         [[             nan,              nan,              nan, ...,
#                        nan,              nan,              nan],
#          [             nan,              nan,              nan, ...,
#                        nan,              nan,              nan],
#          [             nan,              nan,  -1.69655694e+38, ...,
#            -2.64851745e+36,              nan,              nan]]],
#
#
#        [[[             nan,  -2.64843632e+36,              nan, ...,
#                        nan,              nan,              nan],
#          [             nan,              nan,              nan, ...,
#            -2.65845583e+36,              nan,              nan],
#          [             nan,              nan,              nan, ...,
#                        nan,              nan,              nan]],
#
#         [[             nan,              nan,              nan, ...,
#                        nan,              nan,              nan],
#          [ -1.58456316e+29,              nan,  -1.03845931e+34, ...,
#                        nan,              nan,              nan],
#          [             nan,              nan,  -2.65845583e+36, ...,
#                        nan,  -2.65845520e+36,              nan]],
#
#         [[             nan,              nan,              nan, ...,
#                        nan,              nan,              nan],
#          [             nan,              nan,              nan, ...,
#                        nan,              nan,              nan],
#          [ -3.68934859e+19,  -1.70141173e+38,              nan, ...,
#                        nan,              nan,              nan]],
#
#         [[ -2.65845583e+36,              nan,              nan, ...,
#                        nan,              nan,              nan],
#          [             nan,              nan,              nan, ...,
#                        nan,              nan,              nan],
#          [             nan,  -3.68934859e+19,              nan, ...,
#                        nan,  -1.87421127e+38,  -6.69806216e+35]]],
#
#
#        [[[             nan,              nan,              nan, ...,
#            -2.97747051e+38,  -1.71470391e+38,  -1.75458075e+38],
#          [             nan,              nan,              nan, ...,
#                        nan,              nan,              nan],
#          [             nan,              nan,              nan, ...,
#                        nan,  -3.40282347e+38,              nan]],
#
#         [[             nan,              nan,              nan, ...,
#             9.86075603e-32,   2.35098856e-38,   6.01853072e-36],
#          [             nan,              nan,              nan, ...,
#             8.38857550e+06,   2.35098856e-38,   7.99999952e+00],
#          [ -3.40282347e+38,              nan,              nan, ...,
#                        nan,              nan,              nan]],
#
#         [[             nan,              nan,              nan, ...,
#                        nan,              nan,              nan],
#          [             nan,              nan,              nan, ...,
#                        nan,              nan,              nan],
#          [             nan,              nan,              nan, ...,
#            -3.68934859e+19,              nan,              nan]],
#
#         [[             nan,              nan,              nan, ...,
#                        nan,              nan,              nan],
#          [             nan,  -1.55980436e+29,              nan, ...,
#                        nan,              nan,              nan],
#          [             nan,              nan,              nan, ...,
#                        nan,              nan,              nan]]],
#
#
#        [[[             nan,              nan,              nan, ...,
#                        nan,              nan,              nan],
#          [             nan,              nan,              nan, ...,
#                        nan,              nan,              nan],
#          [             nan,              nan,              nan, ...,
#                        nan,              nan,              nan]],
#
#         [[             nan,              nan,              nan, ...,
#                        nan,              nan,  -1.70141173e+38],
#          [             nan,              nan,              nan, ...,
#                        nan,              nan,              nan],
#          [             nan,              nan,              nan, ...,
#                        nan,              nan,              nan]],
#
#         [[             nan,              nan,              nan, ...,
#            -2.65845520e+36,              nan,              nan],
#          [             nan,              nan,              nan, ...,
#                        nan,              nan,              nan],
#          [             nan,              nan,              nan, ...,
#                        nan,              nan,              nan]],
#
#         [[             nan,              nan,              nan, ...,
#                        nan,              nan,              nan],
#          [ -1.70141173e+38,              nan,              nan, ...,
#                        nan,              nan,              nan],
#          [             nan,              nan,              nan, ...,
#                        nan,              nan,              nan]]]], dtype=float32),
#  array([             nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,  -1.70141173e+38,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#         -1.58456316e+29,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#         -1.99999988e+00,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#         -3.29648523e+38,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,  -1.03845931e+34,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,  -3.40282347e+38,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan], dtype=float32),
#  array([[             nan,  -1.03738181e+34,              nan, ...,
#                      nan,              nan,              nan],
#        [             nan,              nan,              nan, ...,
#                      nan,              nan,              nan],
#        [             nan,              nan,              nan, ...,
#                      nan,              nan,              nan],
#        ...,
#        [ -2.77808631e+38,  -2.14005687e+38,              nan, ...,
#           9.18340949e-41,   2.58351916e-29,   2.36934655e-38],
#        [             nan,              nan,              nan, ...,
#                      nan,              nan,              nan],
#        [             nan,              nan,              nan, ...,
#          -2.87113227e+38,   3.68889823e+19,              nan]], dtype=float32),
#  array([             nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,  -1.03845931e+34,
#         -3.45876429e+19,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,  -2.65845583e+36,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#         -1.58456316e+29,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,  -1.99804676e+00,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,  -1.70141173e+38,              nan,
#                     nan,              nan,              nan,
#                     nan,  -4.25352933e+37,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,  -4.25352933e+37,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,  -4.25352933e+37,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,  -3.68934859e+19,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,  -1.70141173e+38,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,  -3.40282347e+38,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,  -3.68934859e+19,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,  -4.25352933e+37,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#         -1.68811945e+38,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,  -3.68934859e+19,
#                     nan], dtype=float32),
#  array([[ -1.18714364e-04,   3.23255017e-06,  -2.58175951e-05, ...,
#           1.47572428e-06,  -9.20509628e-05,  -9.11169263e-05],
#        [ -3.77593533e-05,  -2.90655180e-08,  -1.72519231e-05, ...,
#          -4.74503831e-05,  -2.73257683e-06,  -2.71718236e-05],
#        [ -9.43163559e-06,   8.03241164e-06,   2.03226591e-09, ...,
#           5.45949588e-05,  -2.29210355e-06,  -2.82380697e-05],
#        ...,
#        [  8.23332630e-06,   1.90204282e-05,   1.57650140e-06, ...,
#          -9.92532478e-07,   7.71746167e-10,  -6.09106519e-06],
#        [  9.50520371e-06,   6.03831104e-05,   2.84233829e-05, ...,
#          -9.43233954e-06,   3.95404641e-05,  -3.06052352e-05],
#        [  1.13638671e-05,  -6.95215931e-07,   6.52331437e-06, ...,
#           2.53554790e-05,  -6.18441118e-06,   7.53510903e-07]], dtype=float32),
#  array([             nan,              nan,              nan,
#                     nan,              nan,              nan,
#                     nan,              nan,  -1.58456316e+29,
#                     nan], dtype=float32)]
